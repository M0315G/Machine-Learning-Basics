# %% [markdown]
# ## Practical 4
#
# In this practical, we've implemented the Regularization effect on Machine learning Algorithms. We have implemented regularized algorithms for both:
# - Gradient Descent
# - Normal Equation

# %%
import numpy as np
from sklearn.datasets import load_boston
import pandas as pd
from sklearn.preprocessing import StandardScaler


boston_dataset = load_boston()

# %%
def load_dataset():
    X1 = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
    Y = boston_dataset.target
    
    split = 0.8
    samples = len(X1)
    num = int(split*samples)
    
    x1 = np.ones((len(X1), ))
    X = np.zeros((samples, X1.shape[1]+1))
    X[:,0] = x1
    X[:,1:] = X1
    
    X_train3 = np.array(X[:num, :])
    X_test3 = np.array(X[num:, :])
    Y_train3 = np.array(Y[:num,])
    Y_test3 = np.array(Y[num:,])

    print("The size of X_train is: ",X_train3.shape)
    print("The size of Y_train is: ",Y_train3.shape)
    print("The size of X_test is: ",X_test3.shape)
    print("The size of Y_test is: ",Y_test3.shape)

    return X_train3, Y_train3, X_test3, Y_test3

# %%
def normalize_data(data):
    scaler = StandardScaler()
    scaler.fit(data)
    scaler.transform(data)
    
    return data

# %%
def mse(y_pred, y, theta, lamda=10):
    return np.mean((y - y_pred)**2)+ lamda*(np.dot(theta, theta.T))

# %%
def train(X, y, iters=10000, lr = 0.0000001, lamda=10):
    # Init parameters
    n_samples, n_features = X.shape
    weights = np.zeros(n_features)
    
    for i in range(iters):
        y_pred = np.dot(X, weights)
        
        dw = (1/n_samples)*np.dot(X.T, (y_pred - y)) + (lamda/n_samples)*weights
        
        weights = weights - lr*dw
        
        if(i%500==0):
            cost = mse(y_pred, y, weights)
            print("Cost after iteration ",i," is ", cost)
            
    return weights

# %%
def predict(X, weights):
    y_predicted = np.dot(X, weights)
    return y_predicted

# %% [markdown]
# ### By using Gradient Descent

# %%
X_train3, Y_train3, X_test3, Y_test3 = load_dataset()
X_train3 = normalize_data(X_train3)

# Using Gradinet descent to find the optimized theta
weights=train(X_train3, Y_train3, 700000, 0.000005)
# Out:
# The size of X_train is:  (404, 14)
# The size of Y_train is:  (404,)
# The size of X_test is:  (102, 14)
# The size of Y_test is:  (102,)
# Cost after iteration  0  is  670.0594359019378
# Cost after iteration  500  is  71.68663839191278
# Cost after iteration  1000  is  67.76051444477315
# Cost after iteration  1500  is  64.70825165609276
# Cost after iteration  2000  is  62.2128830762243
# Cost after iteration  2500  is  60.15500032897729
# Cost after iteration  3000  is  58.45938618263345
# Cost after iteration  3500  is  57.06714966326889
# Cost after iteration  4000  is  55.929293786574085
# Cost after iteration  4500  is  55.00452462020883
# Cost after iteration  5000  is  54.257981654722045
# Cost after iteration  5500  is  53.660252144532
# Cost after iteration  6000  is  53.186542281774656
# Cost after iteration  6500  is  52.81597112950834
# Cost after iteration  7000  is  52.5309694421355
# Cost after iteration  7500  is  52.31676881989816
# Cost after iteration  8000  is  52.16096827666325
# Cost after iteration  8500  is  52.05316683998998
# Cost after iteration  9000  is  51.98465231165275
# Cost after iteration  9500  is  51.948137713439884
# Cost after iteration  10000  is  51.9375381845077
# Cost after iteration  10500  is  51.94778217568578
# Cost after iteration  11000  is  51.97465171309755
# Cost after iteration  11500  is  52.01464729481866
# Cost after iteration  12000  is  52.064873657698676
# Cost after iteration  12500  is  52.12294322353474
# Cost after iteration  13000  is  52.18689451932917
# Cost after iteration  13500  is  52.25512327827813
# Cost after iteration  14000  is  52.32632427750643
# Cost after iteration  14500  is  52.39944226483828
# Cost after iteration  15000  is  52.47363057812692
# Cost after iteration  15500  is  52.54821627369244
# Cost after iteration  16000  is  52.62267076104011
# Cost after iteration  16500  is  52.69658509417626
# Cost after iteration  17000  is  52.76964919967849
# Cost after iteration  17500  is  52.84163443175606
# Cost after iteration  18000  is  52.91237893785691
# Cost after iteration  18500  is  52.9817753974871
# Cost after iteration  19000  is  53.04976076396768
# Cost after iteration  19500  is  53.11630769569379
# Cost after iteration  20000  is  53.18141741163531
# Cost after iteration  20500  is  53.24511374664613
# Cost after iteration  21000  is  53.30743821674433
# Cost after iteration  21500  is  53.36844593384044
# Cost after iteration  22000  is  53.42820223422382
# Cost after iteration  22500  is  53.486779906155405
# Cost after iteration  23000  is  53.54425691972989
# Cost after iteration  23500  is  53.60071457725924
# Cost after iteration  24000  is  53.656236015201436
# Cost after iteration  24500  is  53.710904999470465
# Cost after iteration  25000  is  53.76480496511293
# Cost after iteration  25500  is  53.818018259076865
# Cost after iteration  26000  is  53.87062555134493
# Cost after iteration  26500  is  53.92270538523834
# Cost after iteration  27000  is  53.97433384237633
# Cost after iteration  27500  is  54.02558430172721
# Cost after iteration  28000  is  54.07652727552368
# Cost after iteration  28500  is  54.12723030763192
# Cost after iteration  29000  is  54.17775792233859
# Cost after iteration  29500  is  54.22817161352312
# Cost after iteration  30000  is  54.27852986586829
# Cost after iteration  30500  is  54.328888201182856
# Cost after iteration  31000  is  54.37929924410335
# Cost after iteration  31500  is  54.42981280244475
# Cost after iteration  32000  is  54.480475958312375
# Cost after iteration  32500  is  54.531333166791995
# Cost after iteration  33000  is  54.58242635962618
# Cost after iteration  33500  is  54.63379505177791
# Cost after iteration  34000  is  54.685476449194574
# Cost after iteration  34500  is  54.73750555642782
# Cost after iteration  35000  is  54.789915283049396
# Cost after iteration  35500  is  54.842736548039596
# Cost after iteration  36000  is  54.895998381518766
# Cost after iteration  36500  is  54.949728023353366
# Cost after iteration  37000  is  55.003951018299205
# Cost after iteration  37500  is  55.05869130745231
# Cost after iteration  38000  is  55.11397131586398
# Cost after iteration  38500  is  55.169812036247905
# Cost after iteration  39000  is  55.226233108762
# Cost after iteration  39500  is  55.28325289689382
# Cost after iteration  40000  is  55.34088855951086
# Cost after iteration  40500  is  55.399156119166015
# Cost after iteration  41000  is  55.458070526767024
# Cost after iteration  41500  is  55.51764572273391
# Cost after iteration  42000  is  55.57789469477896
# Cost after iteration  42500  is  55.638829532449826
# Cost after iteration  43000  is  55.7004614785806
# Cost after iteration  43500  is  55.762800977796765
# Cost after iteration  44000  is  55.825857722219645
# Cost after iteration  44500  is  55.88964069451414
# Cost after iteration  45000  is  55.95415820841998
# Cost after iteration  45500  is  56.01941794690366
# Cost after iteration  46000  is  56.08542699806304
# Cost after iteration  46500  is  56.15219188891196
# Cost after iteration  47000  is  56.219718617166606
# Cost after iteration  47500  is  56.288012681150654
# Cost after iteration  48000  is  56.35707910792947
# Cost after iteration  48500  is  56.42692247977969
# Cost after iteration  49000  is  56.49754695909344
# Cost after iteration  49500  is  56.5689563118123
# Cost after iteration  50000  is  56.641153929480424
# Cost after iteration  50500  is  56.71414285000073
# Cost after iteration  51000  is  56.787925777174294
# Cost after iteration  51500  is  56.86250509909722
# Cost after iteration  52000  is  56.9378829054857
# Cost after iteration  52500  is  57.014061003995124
# Cost after iteration  53000  is  57.09104093559546
# Cost after iteration  53500  is  57.168823989060925
# Cost after iteration  54000  is  57.24741121462894
# Cost after iteration  54500  is  57.32680343687912
# Cost after iteration  55000  is  57.40700126688036
# Cost after iteration  55500  is  57.488005113651326
# Cost after iteration  56000  is  57.56981519497586
# Cost after iteration  56500  is  57.65243154761302
# Cost after iteration  57000  is  57.73585403693874
# Cost after iteration  57500  is  57.82008236605308
# Cost after iteration  58000  is  57.90511608438629
# Cost after iteration  58500  is  57.990954595832854
# Cost after iteration  59000  is  58.07759716644271
# Cost after iteration  59500  is  58.16504293169572
# Cost after iteration  60000  is  58.25329090338409
# Cost after iteration  60500  is  58.342339976126325
# Cost after iteration  61000  is  58.43218893353415
# Cost after iteration  61500  is  58.52283645405281
# Cost after iteration  62000  is  58.61428111649397
# Cost after iteration  62500  is  58.70652140527875
# Cost after iteration  63000  is  58.799555715408076
# Cost after iteration  63500  is  58.89338235717558
# Cost after iteration  64000  is  58.987999560637924
# Cost after iteration  64500  is  59.08340547985638
# Cost after iteration  65000  is  59.179598196922576
# Cost after iteration  65500  is  59.276575725780475
# Cost after iteration  66000  is  59.37433601585572
# Cost after iteration  66500  is  59.47287695550362
# Cost after iteration  67000  is  59.57219637528532
# Cost after iteration  67500  is  59.67229205108133
# Cost after iteration  68000  is  59.773161707052246
# Cost after iteration  68500  is  59.87480301845379
# Cost after iteration  69000  is  59.97721361431469
# Cost after iteration  69500  is  60.080391079984764
# Cost after iteration  70000  is  60.18433295955949
# Cost after iteration  70500  is  60.289036758188495
# Cost after iteration  71000  is  60.39449994427309
# Cost after iteration  71500  is  60.50071995155963
# Cost after iteration  72000  is  60.60769418113309
# Cost after iteration  72500  is  60.71542000331688
# Cost after iteration  73000  is  60.823894759483196
# Cost after iteration  73500  is  60.933115763778474
# Cost after iteration  74000  is  61.04308030476862
# Cost after iteration  74500  is  61.153785647007595
# Cost after iteration  75000  is  61.26522903253339
# Cost after iteration  75500  is  61.37740768229524
# Cost after iteration  76000  is  61.4903187975149
# Cost after iteration  76500  is  61.603959560985686
# Cost after iteration  77000  is  61.71832713831252
# Cost after iteration  77500  is  61.83341867909512
# Cost after iteration  78000  is  61.94923131805742
# Cost after iteration  78500  is  62.06576217612655
# Cost after iteration  79000  is  62.183008361462264
# Cost after iteration  79500  is  62.30096697044067
# Cost after iteration  80000  is  62.41963508859352
# Cost after iteration  80500  is  62.53900979150529
# Cost after iteration  81000  is  62.659088145670395
# Cost after iteration  81500  is  62.77986720931213
# Cost after iteration  82000  is  62.90134403316501
# Cost after iteration  82500  is  63.023515661222376
# Cost after iteration  83000  is  63.14637913145084
# Cost after iteration  83500  is  63.26993147647313
# Cost after iteration  84000  is  63.394169724220276
# Cost after iteration  84500  is  63.51909089855554
# Cost after iteration  85000  is  63.64469201987077
# Cost after iteration  85500  is  63.77097010565571
# Cost after iteration  86000  is  63.897922171042666
# Cost after iteration  86500  is  64.02554522932752
# Cost after iteration  87000  is  64.15383629246736
# Cost after iteration  87500  is  64.28279237155571
# Cost after iteration  88000  is  64.41241047727785
# Cost after iteration  88500  is  64.54268762034494
# Cost after iteration  89000  is  64.67362081191023
# Cost after iteration  89500  is  64.80520706396577
# Cost after iteration  90000  is  64.937443389722
# Cost after iteration  90500  is  65.07032680397093
# Cost after iteration  91000  is  65.20385432343272
# Cost after iteration  91500  is  65.338022967087
# Cost after iteration  92000  is  65.47282975648972
# Cost after iteration  92500  is  65.60827171607583
# Cost after iteration  93000  is  65.74434587344805
# Cost after iteration  93500  is  65.88104925965354
# Cost after iteration  94000  is  66.01837890944728
# Cost after iteration  94500  is  66.15633186154449
# Cost after iteration  95000  is  66.29490515886091
# Cost after iteration  95500  is  66.43409584874297
# Cost after iteration  96000  is  66.57390098318675
# Cost after iteration  96500  is  66.71431761904759
# Cost after iteration  97000  is  66.85534281823986
# Cost after iteration  97500  is  66.99697364792775
# Cost after iteration  98000  is  67.13920718070689
# Cost after iteration  98500  is  67.2820404947781
# Cost after iteration  99000  is  67.42547067411245
# Cost after iteration  99500  is  67.56949480860916
# Cost after iteration  100000  is  67.71410999424567
# Cost after iteration  100500  is  67.8593133332208
# Cost after iteration  101000  is  68.00510193409109
# Cost after iteration  101500  is  68.15147291190046
# Cost after iteration  102000  is  68.29842338830348
# Cost after iteration  102500  is  68.44595049168336
# Cost after iteration  103000  is  68.5940513572628
# Cost after iteration  103500  is  68.74272312721092
# Cost after iteration  104000  is  68.89196295074353
# Cost after iteration  104500  is  69.04176798421904
# Cost after iteration  105000  is  69.19213539122941
# Cost after iteration  105500  is  69.34306234268578
# Cost after iteration  106000  is  69.49454601690053
# Cost after iteration  106500  is  69.64658359966438
# Cost after iteration  107000  is  69.79917228431964
# Cost after iteration  107500  is  69.95230927182928
# Cost after iteration  108000  is  70.10599177084232
# Cost after iteration  108500  is  70.26021699775538
# Cost after iteration  109000  is  70.4149821767708
# Cost after iteration  109500  is  70.57028453995177
# Cost after iteration  110000  is  70.72612132727346
# Cost after iteration  110500  is  70.88248978667147
# Cost after iteration  111000  is  71.03938717408761
# Cost after iteration  111500  is  71.19681075351185
# Cost after iteration  112000  is  71.35475779702281
# Cost after iteration  112500  is  71.51322558482441
# Cost after iteration  113000  is  71.67221140528052
# Cost after iteration  113500  is  71.83171255494747
# Cost after iteration  114000  is  71.99172633860377
# Cost after iteration  114500  is  72.15225006927747
# Cost after iteration  115000  is  72.31328106827196
# Cost after iteration  115500  is  72.4748166651891
# Cost after iteration  116000  is  72.63685419795061
# Cost after iteration  116500  is  72.79939101281795
# Cost after iteration  117000  is  72.96242446440941
# Cost after iteration  117500  is  73.12595191571631
# Cost after iteration  118000  is  73.2899707381173
# Cost after iteration  118500  is  73.4544783113908
# Cost after iteration  119000  is  73.61947202372612
# Cost after iteration  119500  is  73.78494927173296
# Cost after iteration  120000  is  73.95090746044957
# Cost after iteration  120500  is  74.11734400334964
# Cost after iteration  121000  is  74.28425632234749
# Cost after iteration  121500  is  74.45164184780222
# Cost after iteration  122000  is  74.61949801852117
# Cost after iteration  122500  is  74.78782228176107
# Cost after iteration  123000  is  74.95661209322901
# Cost after iteration  123500  is  75.12586491708214
# Cost after iteration  124000  is  75.2955782259261
# Cost after iteration  124500  is  75.46574950081256
# Cost after iteration  125000  is  75.63637623123606
# Cost after iteration  125500  is  75.80745591512962
# Cost after iteration  126000  is  75.97898605885959
# Cost after iteration  126500  is  76.1509641772197
# Cost after iteration  127000  is  76.32338779342447
# Cost after iteration  127500  is  76.49625443910125
# Cost after iteration  128000  is  76.66956165428252
# Cost after iteration  128500  is  76.84330698739645
# Cost after iteration  129000  is  77.0174879952574
# Cost after iteration  129500  is  77.19210224305598
# Cost after iteration  130000  is  77.36714730434726
# Cost after iteration  130500  is  77.54262076104015
# Cost after iteration  131000  is  77.71852020338504
# Cost after iteration  131500  is  77.89484322996101
# Cost after iteration  132000  is  78.07158744766272
# Cost after iteration  132500  is  78.24875047168698
# Cost after iteration  133000  is  78.42632992551859
# Cost after iteration  133500  is  78.60432344091544
# Cost after iteration  134000  is  78.78272865789394
# Cost after iteration  134500  is  78.96154322471335
# Cost after iteration  135000  is  79.14076479785996
# Cost after iteration  135500  is  79.32039104203105
# Cost after iteration  136000  is  79.50041963011802
# Cost after iteration  136500  is  79.68084824318979
# Cost after iteration  137000  is  79.86167457047534
# Cost after iteration  137500  is  80.04289630934623
# Cost after iteration  138000  is  80.22451116529868
# Cost after iteration  138500  is  80.4065168519356
# Cost after iteration  139000  is  80.58891109094773
# Cost after iteration  139500  is  80.7716916120955
# Cost after iteration  140000  is  80.95485615318964
# Cost after iteration  140500  is  81.1384024600722
# Cost after iteration  141000  is  81.32232828659684
# Cost after iteration  141500  is  81.50663139460985
# Cost after iteration  142000  is  81.69130955392981
# Cost after iteration  142500  is  81.87636054232786
# Cost after iteration  143000  is  82.06178214550678
# Cost after iteration  143500  is  82.24757215708178
# Cost after iteration  144000  is  82.43372837855924
# Cost after iteration  144500  is  82.62024861931599
# Cost after iteration  145000  is  82.80713069657855
# Cost after iteration  145500  is  82.99437243540257
# Cost after iteration  146000  is  83.18197166865087
# Cost after iteration  146500  is  83.36992623697319
# Cost after iteration  147000  is  83.55823398878374
# Cost after iteration  147500  is  83.74689278024098
# Cost after iteration  148000  is  83.93590047522488
# Cost after iteration  148500  is  84.12525494531621
# Cost after iteration  149000  is  84.31495406977405
# Cost after iteration  149500  is  84.50499573551438
# Cost after iteration  150000  is  84.69537783708805
# Cost after iteration  150500  is  84.88609827665886
# Cost after iteration  151000  is  85.07715496398134
# Cost after iteration  151500  is  85.26854581637897
# Cost after iteration  152000  is  85.46026875872144
# Cost after iteration  152500  is  85.65232172340315
# Cost after iteration  153000  is  85.8447026503202
# Cost after iteration  153500  is  86.03740948684904
# Cost after iteration  154000  is  86.230440187823
# Cost after iteration  154500  is  86.42379271551036
# Cost after iteration  155000  is  86.61746503959279
# Cost after iteration  155500  is  86.8114551371414
# Cost after iteration  156000  is  87.00576099259538
# Cost after iteration  156500  is  87.20038059773862
# Cost after iteration  157000  is  87.39531195167842
# Cost after iteration  157500  is  87.59055306082203
# Cost after iteration  158000  is  87.78610193885453
# Cost after iteration  158500  is  87.98195660671605
# Cost after iteration  159000  is  88.17811509257932
# Cost after iteration  159500  is  88.37457543182715
# Cost after iteration  160000  is  88.57133566703045
# Cost after iteration  160500  is  88.76839384792429
# Cost after iteration  161000  is  88.96574803138736
# Cost after iteration  161500  is  89.16339628141758
# Cost after iteration  162000  is  89.36133666911039
# Cost after iteration  162500  is  89.5595672726369
# Cost after iteration  163000  is  89.7580861772208
# Cost after iteration  163500  is  89.9568914751151
# Cost after iteration  164000  is  90.15598126558118
# Cost after iteration  164500  is  90.35535365486595
# Cost after iteration  165000  is  90.55500675617863
# Cost after iteration  165500  is  90.75493868966947
# Cost after iteration  166000  is  90.95514758240677
# Cost after iteration  166500  is  91.15563156835515
# Cost after iteration  167000  is  91.35638878835235
# Cost after iteration  167500  is  91.55741739008795
# Cost after iteration  168000  is  91.75871552808051
# Cost after iteration  168500  is  91.96028136365588
# Cost after iteration  169000  is  92.16211306492484
# Cost after iteration  169500  is  92.36420880676056
# Cost after iteration  170000  is  92.56656677077783
# Cost after iteration  170500  is  92.76918514530954
# Cost after iteration  171000  is  92.97206212538583
# Cost after iteration  171500  is  93.1751959127111
# Cost after iteration  172000  is  93.37858471564348
# Cost after iteration  172500  is  93.5822267491718
# Cost after iteration  173000  is  93.78612023489376
# Cost after iteration  173500  is  93.99026340099547
# Cost after iteration  174000  is  94.19465448222863
# Cost after iteration  174500  is  94.39929171988896
# Cost after iteration  175000  is  94.6041733617947
# Cost after iteration  175500  is  94.80929766226518
# Cost after iteration  176000  is  95.0146628820992
# Cost after iteration  176500  is  95.22026728855346
# Cost after iteration  177000  is  95.42610915532151
# Cost after iteration  177500  is  95.63218676251228
# Cost after iteration  178000  is  95.83849839662787
# Cost after iteration  178500  is  96.0450423505441
# Cost after iteration  179000  is  96.25181692348725
# Cost after iteration  179500  is  96.45882042101442
# Cost after iteration  180000  is  96.66605115499213
# Cost after iteration  180500  is  96.8735074435748
# Cost after iteration  181000  is  97.08118761118415
# Cost after iteration  181500  is  97.28908998848799
# Cost after iteration  182000  is  97.49721291237967
# Cost after iteration  182500  is  97.70555472595714
# Cost after iteration  183000  is  97.91411377850194
# Cost after iteration  183500  is  98.12288842545885
# Cost after iteration  184000  is  98.33187702841522
# Cost after iteration  184500  is  98.54107795507994
# Cost after iteration  185000  is  98.75048957926373
# Cost after iteration  185500  is  98.96011028085792
# Cost after iteration  186000  is  99.1699384458141
# Cost after iteration  186500  is  99.37997246612434
# Cost after iteration  187000  is  99.59021073980026
# Cost after iteration  187500  is  99.80065167085286
# Cost after iteration  188000  is  100.0112936692731
# Cost after iteration  188500  is  100.22213515101102
# Cost after iteration  189000  is  100.4331745379556
# Cost after iteration  189500  is  100.64441025791521
# Cost after iteration  190000  is  100.85584074459784
# Cost after iteration  190500  is  101.06746443759016
# Cost after iteration  191000  is  101.27927978233899
# Cost after iteration  191500  is  101.49128523013093
# Cost after iteration  192000  is  101.70347923807259
# Cost after iteration  192500  is  101.91586026907129
# Cost after iteration  193000  is  102.12842679181499
# Cost after iteration  193500  is  102.34117728075367
# Cost after iteration  194000  is  102.55411021607848
# Cost after iteration  194500  is  102.76722408370387
# Cost after iteration  195000  is  102.98051737524702
# Cost after iteration  195500  is  103.19398858800955
# Cost after iteration  196000  is  103.40763622495751
# Cost after iteration  196500  is  103.62145879470307
# Cost after iteration  197000  is  103.83545481148442
# Cost after iteration  197500  is  104.04962279514763
# Cost after iteration  198000  is  104.26396127112714
# Cost after iteration  198500  is  104.47846877042707
# Cost after iteration  199000  is  104.69314382960272
# Cost after iteration  199500  is  104.9079849907408
# Cost after iteration  200000  is  105.12299080144186
# Cost after iteration  200500  is  105.33815981480127
# Cost after iteration  201000  is  105.55349058938961
# Cost after iteration  201500  is  105.76898168923616
# Cost after iteration  202000  is  105.98463168380849
# Cost after iteration  202500  is  106.20043914799504
# Cost after iteration  203000  is  106.41640266208668
# Cost after iteration  203500  is  106.632520811758
# Cost after iteration  204000  is  106.84879218804922
# Cost after iteration  204500  is  107.06521538734916
# Cost after iteration  205000  is  107.28178901137497
# Cost after iteration  205500  is  107.49851166715565
# Cost after iteration  206000  is  107.71538196701405
# Cost after iteration  206500  is  107.93239852854816
# Cost after iteration  207000  is  108.1495599746136
# Cost after iteration  207500  is  108.36686493330558
# Cost after iteration  208000  is  108.58431203794198
# Cost after iteration  208500  is  108.8018999270447
# Cost after iteration  209000  is  109.01962724432252
# Cost after iteration  209500  is  109.23749263865324
# Cost after iteration  210000  is  109.45549476406637
# Cost after iteration  210500  is  109.67363227972572
# Cost after iteration  211000  is  109.89190384991201
# Cost after iteration  211500  is  110.11030814400553
# Cost after iteration  212000  is  110.32884383646864
# Cost after iteration  212500  is  110.5475096068281
# Cost after iteration  213000  is  110.76630413965935
# Cost after iteration  213500  is  110.98522612456826
# Cost after iteration  214000  is  111.20427425617464
# Cost after iteration  214500  is  111.4234472340942
# Cost after iteration  215000  is  111.64274376292315
# Cost after iteration  215500  is  111.86216255222024
# Cost after iteration  216000  is  112.08170231649035
# Cost after iteration  216500  is  112.3013617751679
# Cost after iteration  217000  is  112.52113965259994
# Cost after iteration  217500  is  112.74103467802905
# Cost after iteration  218000  is  112.96104558557786
# Cost after iteration  218500  is  113.18117111423146
# Cost after iteration  219000  is  113.40141000782117
# Cost after iteration  219500  is  113.62176101500879
# Cost after iteration  220000  is  113.84222288926915
# Cost after iteration  220500  is  114.06279438887505
# Cost after iteration  221000  is  114.28347427688018
# Cost after iteration  221500  is  114.50426132110312
# Cost after iteration  222000  is  114.72515429411094
# Cost after iteration  222500  is  114.94615197320395
# Cost after iteration  223000  is  115.16725314039837
# Cost after iteration  223500  is  115.38845658241189
# Cost after iteration  224000  is  115.60976109064701
# Cost after iteration  224500  is  115.83116546117408
# Cost after iteration  225000  is  116.0526684947178
# Cost after iteration  225500  is  116.27426899663973
# Cost after iteration  226000  is  116.49596577692306
# Cost after iteration  226500  is  116.7177576501571
# Cost after iteration  227000  is  116.93964343552189
# Cost after iteration  227500  is  117.16162195677188
# Cost after iteration  228000  is  117.3836920422217
# Cost after iteration  228500  is  117.60585252472963
# Cost after iteration  229000  is  117.82810224168227
# Cost after iteration  229500  is  118.05044003498054
# Cost after iteration  230000  is  118.27286475102267
# Cost after iteration  230500  is  118.49537524068967
# Cost after iteration  231000  is  118.71797035933092
# Cost after iteration  231500  is  118.94064896674811
# Cost after iteration  232000  is  119.16340992718035
# Cost after iteration  232500  is  119.38625210928925
# Cost after iteration  233000  is  119.60917438614446
# Cost after iteration  233500  is  119.83217563520823
# Cost after iteration  234000  is  120.05525473832067
# Cost after iteration  234500  is  120.27841058168468
# Cost after iteration  235000  is  120.5016420558519
# Cost after iteration  235500  is  120.72494805570729
# Cost after iteration  236000  is  120.94832748045502
# Cost after iteration  236500  is  121.17177923360369
# Cost after iteration  237000  is  121.39530222295173
# Cost after iteration  237500  is  121.6188953605733
# Cost after iteration  238000  is  121.84255756280261
# Cost after iteration  238500  is  122.06628775022183
# Cost after iteration  239000  is  122.29008484764425
# Cost after iteration  239500  is  122.5139477841016
# Cost after iteration  240000  is  122.73787549282896
# Cost after iteration  240500  is  122.96186691125178
# Cost after iteration  241000  is  123.18592098096971
# Cost after iteration  241500  is  123.4100366477441
# Cost after iteration  242000  is  123.63421286148423
# Cost after iteration  242500  is  123.85844857623186
# Cost after iteration  243000  is  124.08274275014851
# Cost after iteration  243500  is  124.30709434550143
# Cost after iteration  244000  is  124.53150232864782
# Cost after iteration  244500  is  124.75596567002478
# Cost after iteration  245000  is  124.98048334413225
# Cost after iteration  245500  is  125.20505432952076
# Cost after iteration  246000  is  125.42967760877704
# Cost after iteration  246500  is  125.65435216851179
# Cost after iteration  247000  is  125.8790769993444
# Cost after iteration  247500  is  126.10385109589048
# Cost after iteration  248000  is  126.3286734567485
# Cost after iteration  248500  is  126.5535430844854
# Cost after iteration  249000  is  126.77845898562441
# Cost after iteration  249500  is  127.00342017063049
# Cost after iteration  250000  is  127.22842565389841
# Cost after iteration  250500  is  127.45347445373815
# Cost after iteration  251000  is  127.67856559236307
# Cost after iteration  251500  is  127.9036980958758
# Cost after iteration  252000  is  128.12887099425456
# Cost after iteration  252500  is  128.35408332134233
# Cost after iteration  253000  is  128.57933411483128
# Cost after iteration  253500  is  128.80462241625156
# Cost after iteration  254000  is  129.02994727095816
# Cost after iteration  254500  is  129.25530772811692
# Cost after iteration  255000  is  129.480702840692
# Cost after iteration  255500  is  129.7061316654356
# Cost after iteration  256000  is  129.9315932628709
# Cost after iteration  256500  is  130.1570866972829
# Cost after iteration  257000  is  130.3826110367043
# Cost after iteration  257500  is  130.60816535290283
# Cost after iteration  258000  is  130.8337487213689
# Cost after iteration  258500  is  131.05936022130348
# Cost after iteration  259000  is  131.2849989356048
# Cost after iteration  259500  is  131.51066395085675
# Cost after iteration  260000  is  131.736354357316
# Cost after iteration  260500  is  131.9620692488996
# Cost after iteration  261000  is  132.1878077231728
# Cost after iteration  261500  is  132.41356888133663
# Cost after iteration  262000  is  132.63935182821632
# Cost after iteration  262500  is  132.86515567224845
# Cost after iteration  263000  is  133.0909795254691
# Cost after iteration  263500  is  133.31682250350096
# Cost after iteration  264000  is  133.54268372554287
# Cost after iteration  264500  is  133.76856231435698
# Cost after iteration  265000  is  133.99445739625511
# Cost after iteration  265500  is  134.2203681010902
# Cost after iteration  266000  is  134.44629356224178
# Cost after iteration  266500  is  134.67223291660525
# Cost after iteration  267000  is  134.8981853045788
# Cost after iteration  267500  is  135.12414987005428
# Cost after iteration  268000  is  135.3501257604025
# Cost after iteration  268500  is  135.57611212646285
# Cost after iteration  269000  is  135.80210812253253
# Cost after iteration  269500  is  136.02811290635353
# Cost after iteration  270000  is  136.25412563910112
# Cost after iteration  270500  is  136.4801454853727
# Cost after iteration  271000  is  136.7061716131778
# Cost after iteration  271500  is  136.93220319392404
# Cost after iteration  272000  is  137.15823940240688
# Cost after iteration  272500  is  137.38427941679845
# Cost after iteration  273000  is  137.6103224186357
# Cost after iteration  273500  is  137.83636759281
# Cost after iteration  274000  is  138.06241412755497
# Cost after iteration  274500  is  138.28846121443542
# Cost after iteration  275000  is  138.51450804833658
# Cost after iteration  275500  is  138.7405538274526
# Cost after iteration  276000  is  138.96659775327518
# Cost after iteration  276500  is  139.19263903058388
# Cost after iteration  277000  is  139.41867686743277
# Cost after iteration  277500  is  139.64471047514144
# Cost after iteration  278000  is  139.87073906828402
# Cost after iteration  278500  is  140.09676186467573
# Cost after iteration  279000  is  140.32277808536597
# Cost after iteration  279500  is  140.54878695462358
# Cost after iteration  280000  is  140.77478769992922
# Cost after iteration  280500  is  141.00077955196213
# Cost after iteration  281000  is  141.2267617445912
# Cost after iteration  281500  is  141.4527335148627
# Cost after iteration  282000  is  141.67869410299124
# Cost after iteration  282500  is  141.90464275234746
# Cost after iteration  283000  is  142.13057870945
# Cost after iteration  283500  is  142.3565012239512
# Cost after iteration  284000  is  142.5824095486306
# Cost after iteration  284500  is  142.80830293938155
# Cost after iteration  285000  is  143.0341806552009
# Cost after iteration  285500  is  143.26004195818044
# Cost after iteration  286000  is  143.48588611349592
# Cost after iteration  286500  is  143.71171238939527
# Cost after iteration  287000  is  143.9375200571899
# Cost after iteration  287500  is  144.16330839124376
# Cost after iteration  288000  is  144.38907666896264
# Cost after iteration  288500  is  144.6148241707851
# Cost after iteration  289000  is  144.84055018017176
# Cost after iteration  289500  is  145.06625398359526
# Cost after iteration  290000  is  145.29193487052902
# Cost after iteration  290500  is  145.51759213343908
# Cost after iteration  291000  is  145.74322506777298
# Cost after iteration  291500  is  145.96883297195023
# Cost after iteration  292000  is  146.19441514735124
# Cost after iteration  292500  is  146.41997089830866
# Cost after iteration  293000  is  146.64549953209695
# Cost after iteration  293500  is  146.87100035892342
# Cost after iteration  294000  is  147.09647269191626
# Cost after iteration  294500  is  147.32191584711668
# Cost after iteration  295000  is  147.54732914346903
# Cost after iteration  295500  is  147.7727119028092
# Cost after iteration  296000  is  147.9980634498572
# Cost after iteration  296500  is  148.2233831122067
# Cost after iteration  297000  is  148.44867022031582
# Cost after iteration  297500  is  148.67392410749494
# Cost after iteration  298000  is  148.89914410990065
# Cost after iteration  298500  is  149.12432956652472
# Cost after iteration  299000  is  149.34947981918424
# Cost after iteration  299500  is  149.57459421251284
# Cost after iteration  300000  is  149.7996720939505
# Cost after iteration  300500  is  150.02471281373516
# Cost after iteration  301000  is  150.24971572489147
# Cost after iteration  301500  is  150.47468018322408
# Cost after iteration  302000  is  150.6996055473066
# Cost after iteration  302500  is  150.92449117847158
# Cost after iteration  303000  is  151.14933644080386
# Cost after iteration  303500  is  151.37414070112908
# Cost after iteration  304000  is  151.5989033290046
# Cost after iteration  304500  is  151.82362369671299
# Cost after iteration  305000  is  152.04830117924843
# Cost after iteration  305500  is  152.27293515431097
# Cost after iteration  306000  is  152.49752500229764
# Cost after iteration  306500  is  152.7220701062907
# Cost after iteration  307000  is  152.94656985205094
# Cost after iteration  307500  is  153.17102362800833
# Cost after iteration  308000  is  153.39543082525196
# Cost after iteration  308500  is  153.6197908375217
# Cost after iteration  309000  is  153.8441030612006
# Cost after iteration  309500  is  154.06836689530402
# Cost after iteration  310000  is  154.29258174147213
# Cost after iteration  310500  is  154.51674700396097
# Cost after iteration  311000  is  154.7408620896324
# Cost after iteration  311500  is  154.96492640794708
# Cost after iteration  312000  is  155.18893937095402
# Cost after iteration  312500  is  155.41290039328427
# Cost after iteration  313000  is  155.63680889213995
# Cost after iteration  313500  is  155.86066428728668
# Cost after iteration  314000  is  156.08446600104526
# Cost after iteration  314500  is  156.30821345828213
# Cost after iteration  315000  is  156.53190608640162
# Cost after iteration  315500  is  156.75554331533684
# Cost after iteration  316000  is  156.9791245775416
# Cost after iteration  316500  is  157.2026493079821
# Cost after iteration  317000  is  157.42611694412807
# Cost after iteration  317500  is  157.64952692594557
# Cost after iteration  318000  is  157.87287869588528
# Cost after iteration  318500  is  158.0961716988793
# Cost after iteration  319000  is  158.31940538232752
# Cost after iteration  319500  is  158.5425791960932
# Cost after iteration  320000  is  158.7656925924928
# Cost after iteration  320500  is  158.9887450262883
# Cost after iteration  321000  is  159.21173595467937
# Cost after iteration  321500  is  159.4346648372939
# Cost after iteration  322000  is  159.65753113618103
# Cost after iteration  322500  is  159.88033431580376
# Cost after iteration  323000  is  160.10307384302814
# Cost after iteration  323500  is  160.32574918711742
# Cost after iteration  324000  is  160.54835981972323
# Cost after iteration  324500  is  160.77090521487827
# Cost after iteration  325000  is  160.9933848489872
# Cost after iteration  325500  is  161.2157982008189
# Cost after iteration  326000  is  161.4381447514999
# Cost after iteration  326500  is  161.66042398450432
# Cost after iteration  327000  is  161.88263538564777
# Cost after iteration  327500  is  162.1047784430785
# Cost after iteration  328000  is  162.32685264726973
# Cost after iteration  328500  is  162.54885749101163
# Cost after iteration  329000  is  162.77079246940463
# Cost after iteration  329500  is  162.99265707984983
# Cost after iteration  330000  is  163.21445082204255
# Cost after iteration  330500  is  163.4361731979652
# Cost after iteration  331000  is  163.65782371187737
# Cost after iteration  331500  is  163.8794018703104
# Cost after iteration  332000  is  164.10090718205876
# Cost after iteration  332500  is  164.32233915817216
# Cost after iteration  333000  is  164.54369731194822
# Cost after iteration  333500  is  164.76498115892582
# Cost after iteration  334000  is  164.98619021687597
# Cost after iteration  334500  is  165.20732400579456
# Cost after iteration  335000  is  165.42838204789723
# Cost after iteration  335500  is  165.649363867608
# Cost after iteration  336000  is  165.87026899155504
# Cost after iteration  336500  is  166.09109694856153
# Cost after iteration  337000  is  166.31184726963858
# Cost after iteration  337500  is  166.53251948797916
# Cost after iteration  338000  is  166.75311313894878
# Cost after iteration  338500  is  166.97362776007913
# Cost after iteration  339000  is  167.19406289106072
# Cost after iteration  339500  is  167.41441807373604
# Cost after iteration  340000  is  167.63469285209132
# Cost after iteration  340500  is  167.85488677224976
# Cost after iteration  341000  is  168.07499938246525
# Cost after iteration  341500  is  168.2950302331136
# Cost after iteration  342000  is  168.51497887668594
# Cost after iteration  342500  is  168.73484486778264
# Cost after iteration  343000  is  168.9546277631046
# Cost after iteration  343500  is  169.1743271214466
# Cost after iteration  344000  is  169.3939425036911
# Cost after iteration  344500  is  169.6134734728005
# Cost after iteration  345000  is  169.83291959381103
# Cost after iteration  345500  is  170.0522804338229
# Cost after iteration  346000  is  170.27155556199725
# Cost after iteration  346500  is  170.4907445495466
# Cost after iteration  347000  is  170.70984696972832
# Cost after iteration  347500  is  170.92886239783883
# Cost after iteration  348000  is  171.14779041120542
# Cost after iteration  348500  is  171.36663058917938
# Cost after iteration  349000  is  171.58538251313087
# Cost after iteration  349500  is  171.80404576644034
# Cost after iteration  350000  is  172.02261993449162
# Cost after iteration  350500  is  172.24110460466693
# Cost after iteration  351000  is  172.45949936633826
# Cost after iteration  351500  is  172.67780381086166
# Cost after iteration  352000  is  172.8960175315698
# Cost after iteration  352500  is  173.1141401237674
# Cost after iteration  353000  is  173.3321711847203
# Cost after iteration  353500  is  173.5501103136534
# Cost after iteration  354000  is  173.7679571117415
# Cost after iteration  354500  is  173.98571118210253
# Cost after iteration  355000  is  174.20337212979337
# Cost after iteration  355500  is  174.4209395617999
# Cost after iteration  356000  is  174.63841308703311
# Cost after iteration  356500  is  174.8557923163211
# Cost after iteration  357000  is  175.07307686240338
# Cost after iteration  357500  is  175.29026633992453
# Cost after iteration  358000  is  175.5073603654267
# Cost after iteration  358500  is  175.72435855734378
# Cost after iteration  359000  is  175.94126053599598
# Cost after iteration  359500  is  176.15806592358138
# Cost after iteration  360000  is  176.37477434417133
# Cost after iteration  360500  is  176.591385423703
# Cost after iteration  361000  is  176.80789878997368
# Cost after iteration  361500  is  177.02431407263452
# Cost after iteration  362000  is  177.24063090318333
# Cost after iteration  362500  is  177.45684891496006
# Cost after iteration  363000  is  177.6729677431384
# Cost after iteration  363500  is  177.88898702472105
# Cost after iteration  364000  is  178.10490639853342
# Cost after iteration  364500  is  178.32072550521588
# Cost after iteration  365000  is  178.5364439872197
# Cost after iteration  365500  is  178.7520614888
# Cost after iteration  366000  is  178.967577656009
# Cost after iteration  366500  is  179.18299213669133
# Cost after iteration  367000  is  179.39830458047723
# Cost after iteration  367500  is  179.61351463877514
# Cost after iteration  368000  is  179.82862196476796
# Cost after iteration  368500  is  180.04362621340502
# Cost after iteration  369000  is  180.25852704139794
# Cost after iteration  369500  is  180.47332410721293
# Cost after iteration  370000  is  180.68801707106627
# Cost after iteration  370500  is  180.90260559491716
# Cost after iteration  371000  is  181.11708934246232
# Cost after iteration  371500  is  181.331467979129
# Cost after iteration  372000  is  181.54574117207176
# Cost after iteration  372500  is  181.75990859016392
# Cost after iteration  373000  is  181.97396990399338
# Cost after iteration  373500  is  182.1879247858558
# Cost after iteration  374000  is  182.40177290974802
# Cost after iteration  374500  is  182.6155139513647
# Cost after iteration  375000  is  182.8291475880899
# Cost after iteration  375500  is  183.04267349899362
# Cost after iteration  376000  is  183.25609136482447
# Cost after iteration  376500  is  183.46940086800467
# Cost after iteration  377000  is  183.6826016926229
# Cost after iteration  377500  is  183.89569352443206
# Cost after iteration  378000  is  184.10867605083914
# Cost after iteration  378500  is  184.32154896090256
# Cost after iteration  379000  is  184.53431194532584
# Cost after iteration  379500  is  184.7469646964517
# Cost after iteration  380000  is  184.95950690825632
# Cost after iteration  380500  is  185.17193827634446
# Cost after iteration  381000  is  185.38425849794285
# Cost after iteration  381500  is  185.59646727189585
# Cost after iteration  382000  is  185.80856429865946
# Cost after iteration  382500  is  186.0205492802948
# Cost after iteration  383000  is  186.2324219204636
# Cost after iteration  383500  is  186.44418192442294
# Cost after iteration  384000  is  186.6558289990197
# Cost after iteration  384500  is  186.86736285268384
# Cost after iteration  385000  is  187.07878319542493
# Cost after iteration  385500  is  187.29008973882455
# Cost after iteration  386000  is  187.5012821960339
# Cost after iteration  386500  is  187.71236028176492
# Cost after iteration  387000  is  187.92332371228758
# Cost after iteration  387500  is  188.13417220542195
# Cost after iteration  388000  is  188.34490548053705
# Cost after iteration  388500  is  188.55552325854126
# Cost after iteration  389000  is  188.76602526187915
# Cost after iteration  389500  is  188.97641121452529
# Cost after iteration  390000  is  189.18668084198046
# Cost after iteration  390500  is  189.39683387126496
# Cost after iteration  391000  is  189.60687003091383
# Cost after iteration  391500  is  189.8167890509718
# Cost after iteration  392000  is  190.0265906629873
# Cost after iteration  392500  is  190.23627460000895
# Cost after iteration  393000  is  190.44584059657856
# Cost after iteration  393500  is  190.65528838872683
# Cost after iteration  394000  is  190.86461771396887
# Cost after iteration  394500  is  191.07382831129766
# Cost after iteration  395000  is  191.2829199211809
# Cost after iteration  395500  is  191.49189228555346
# Cost after iteration  396000  is  191.70074514781396
# Cost after iteration  396500  is  191.90947825281967
# Cost after iteration  397000  is  192.11809134688042
# Cost after iteration  397500  is  192.32658417775474
# Cost after iteration  398000  is  192.53495649464517
# Cost after iteration  398500  is  192.7432080481912
# Cost after iteration  399000  is  192.95133859046555
# Cost after iteration  399500  is  193.1593478749715
# Cost after iteration  400000  is  193.3672356566332
# Cost after iteration  400500  is  193.57500169179445
# Cost after iteration  401000  is  193.78264573821278
# Cost after iteration  401500  is  193.99016755505474
# Cost after iteration  402000  is  194.19756690288943
# Cost after iteration  402500  is  194.4048435436859
# Cost after iteration  403000  is  194.61199724080666
# Cost after iteration  403500  is  194.8190277590042
# Cost after iteration  404000  is  195.0259348644147
# Cost after iteration  404500  is  195.23271832455484
# Cost after iteration  405000  is  195.43937790831623
# Cost after iteration  405500  is  195.64591338595898
# Cost after iteration  406000  is  195.85232452910984
# Cost after iteration  406500  is  196.05861111075706
# Cost after iteration  407000  is  196.26477290524235
# Cost after iteration  407500  is  196.47080968826063
# Cost after iteration  408000  is  196.67672123685227
# Cost after iteration  408500  is  196.88250732940054
# Cost after iteration  409000  is  197.08816774562476
# Cost after iteration  409500  is  197.29370226657682
# Cost after iteration  410000  is  197.49911067463663
# Cost after iteration  410500  is  197.70439275350745
# Cost after iteration  411000  is  197.90954828821154
# Cost after iteration  411500  is  198.11457706508418
# Cost after iteration  412000  is  198.31947887177134
# Cost after iteration  412500  is  198.52425349722188
# Cost after iteration  413000  is  198.72890073168753
# Cost after iteration  413500  is  198.9334203667141
# Cost after iteration  414000  is  199.13781219513862
# Cost after iteration  414500  is  199.34207601108602
# Cost after iteration  415000  is  199.54621160996206
# Cost after iteration  415500  is  199.75021878845226
# Cost after iteration  416000  is  199.95409734451297
# Cost after iteration  416500  is  200.15784707737154
# Cost after iteration  417000  is  200.36146778751876
# Cost after iteration  417500  is  200.56495927670522
# Cost after iteration  418000  is  200.7683213479376
# Cost after iteration  418500  is  200.9715538054738
# Cost after iteration  419000  is  201.1746564548181
# Cost after iteration  419500  is  201.377629102718
# Cost after iteration  420000  is  201.58047155715832
# Cost after iteration  420500  is  201.7831836273582
# Cost after iteration  421000  is  201.98576512376593
# Cost after iteration  421500  is  202.18821585805463
# Cost after iteration  422000  is  202.3905356431193
# Cost after iteration  422500  is  202.59272429307006
# Cost after iteration  423000  is  202.79478162323008
# Cost after iteration  423500  is  202.99670745013063
# Cost after iteration  424000  is  203.19850159150621
# Cost after iteration  424500  is  203.4001638662926
# Cost after iteration  425000  is  203.60169409461764
# Cost after iteration  425500  is  203.80309209780285
# Cost after iteration  426000  is  204.00435769835633
# Cost after iteration  426500  is  204.20549071996672
# Cost after iteration  427000  is  204.40649098750464
# Cost after iteration  427500  is  204.60735832701394
# Cost after iteration  428000  is  204.8080925657082
# Cost after iteration  428500  is  205.0086935319655
# Cost after iteration  429000  is  205.20916105532885
# Cost after iteration  429500  is  205.409494966498
# Cost after iteration  430000  is  205.60969509732712
# Cost after iteration  430500  is  205.80976128081883
# Cost after iteration  431000  is  206.00969335112225
# Cost after iteration  431500  is  206.20949114352803
# Cost after iteration  432000  is  206.4091544944642
# Cost after iteration  432500  is  206.6086832414925
# Cost after iteration  433000  is  206.80807722330456
# Cost after iteration  433500  is  207.00733627971854
# Cost after iteration  434000  is  207.2064602516726
# Cost after iteration  434500  is  207.4054489812226
# Cost after iteration  435000  is  207.60430231153822
# Cost after iteration  435500  is  207.80302008689878
# Cost after iteration  436000  is  208.00160215268997
# Cost after iteration  436500  is  208.20004835539942
# Cost after iteration  437000  is  208.3983585426122
# Cost after iteration  437500  is  208.5965325630075
# Cost after iteration  438000  is  208.79457026635308
# Cost after iteration  438500  is  208.99247150350539
# Cost after iteration  439000  is  209.1902361264028
# Cost after iteration  439500  is  209.38786398806212
# Cost after iteration  440000  is  209.58535494257325
# Cost after iteration  440500  is  209.7827088450988
# Cost after iteration  441000  is  209.9799255518675
# Cost after iteration  441500  is  210.17700492017258
# Cost after iteration  442000  is  210.37394680836408
# Cost after iteration  442500  is  210.5707510758515
# Cost after iteration  443000  is  210.767417583093
# Cost after iteration  443500  is  210.9639461915953
# Cost after iteration  444000  is  211.16033676391123
# Cost after iteration  444500  is  211.35658916363337
# Cost after iteration  445000  is  211.55270325539044
# Cost after iteration  445500  is  211.74867890484694
# Cost after iteration  446000  is  211.9445159786939
# Cost after iteration  446500  is  212.14021434465002
# Cost after iteration  447000  is  212.33577387145522
# Cost after iteration  447500  is  212.5311944288684
# Cost after iteration  448000  is  212.72647588766264
# Cost after iteration  448500  is  212.92161811962427
# Cost after iteration  449000  is  213.11662099754537
# Cost after iteration  449500  is  213.3114843952226
# Cost after iteration  450000  is  213.5062081874532
# Cost after iteration  450500  is  213.70079225003025
# Cost after iteration  451000  is  213.89523645974018
# Cost after iteration  451500  is  214.08954069436052
# Cost after iteration  452000  is  214.2837048326534
# Cost after iteration  452500  is  214.4777287543648
# Cost after iteration  453000  is  214.67161234021728
# Cost after iteration  453500  is  214.86535547191264
# Cost after iteration  454000  is  215.05895803211973
# Cost after iteration  454500  is  215.25241990447793
# Cost after iteration  455000  is  215.44574097359464
# Cost after iteration  455500  is  215.63892112503382
# Cost after iteration  456000  is  215.83196024532032
# Cost after iteration  456500  is  216.02485822193273
# Cost after iteration  457000  is  216.2176149433017
# Cost after iteration  457500  is  216.4102302988045
# Cost after iteration  458000  is  216.60270417876055
# ...
# Cost after iteration  547500  is  248.70644952634487
# Cost after iteration  548000  is  248.8724654454599
# Cost after iteration  548500  is  249.0383325870477
# Cost after iteration  549000  is  249.20405096571739
# Cost after iteration  549500  is  249.3696205965438
# Cost after iteration  550000  is  249.5350414950687
# Cost after iteration  550500  is  249.70031367729376
# Cost after iteration  551000  is  249.8654371596884
# Cost after iteration  551500  is  250.03041195917504
# Cost after iteration  552000  is  250.19523809313873
# Cost after iteration  552500  is  250.35991557941782
# Cost after iteration  553000  is  250.52444443630696
# Cost after iteration  553500  is  250.6888246825508
# Cost after iteration  554000  is  250.85305633734546
# Cost after iteration  554500  is  251.0171394203347
# Cost after iteration  555000  is  251.18107395160922
# Cost after iteration  555500  is  251.34485995170462
# Cost after iteration  556000  is  251.5084974415975
# Cost after iteration  556500  is  251.67198644270798
# Cost after iteration  557000  is  251.8353269768942
# Cost after iteration  557500  is  251.99851906645148
# Cost after iteration  558000  is  252.161562734111
# Cost after iteration  558500  is  252.32445800303805
# Cost after iteration  559000  is  252.4872048968267
# Cost after iteration  559500  is  252.6498034395064
# Cost after iteration  560000  is  252.81225365552933
# Cost after iteration  560500  is  252.97455556977786
# Cost after iteration  561000  is  253.13670920755672
# Cost after iteration  561500  is  253.29871459459562
# Cost after iteration  562000  is  253.46057175704374
# Cost after iteration  562500  is  253.62228072147002
# Cost after iteration  563000  is  253.78384151486145
# Cost after iteration  563500  is  253.9452541646182
# Cost after iteration  564000  is  254.10651869855923
# Cost after iteration  564500  is  254.267635144911
# Cost after iteration  565000  is  254.4286035323144
# Cost after iteration  565500  is  254.5894238898151
# Cost after iteration  566000  is  254.7500962468688
# Cost after iteration  566500  is  254.91062063333632
# Cost after iteration  567000  is  255.0709970794787
# Cost after iteration  567500  is  255.2312256159637
# Cost after iteration  568000  is  255.391306273856
# Cost after iteration  568500  is  255.55123908462002
# Cost after iteration  569000  is  255.71102408011546
# Cost after iteration  569500  is  255.87066129259992
# Cost after iteration  570000  is  256.0301507547212
# Cost after iteration  570500  is  256.1894924995194
# Cost after iteration  571000  is  256.3486865604265
# Cost after iteration  571500  is  256.5077329712607
# Cost after iteration  572000  is  256.6666317662273
# Cost after iteration  572500  is  256.82538297991744
# Cost after iteration  573000  is  256.9839866473052
# Cost after iteration  573500  is  257.1424428037448
# Cost after iteration  574000  is  257.30075148497315
# Cost after iteration  574500  is  257.4589127271035
# Cost after iteration  575000  is  257.6169265666252
# Cost after iteration  575500  is  257.7747930404056
# Cost after iteration  576000  is  257.9325121856819
# Cost after iteration  576500  is  258.09008404006545
# Cost after iteration  577000  is  258.2475086415377
# Cost after iteration  577500  is  258.40478602844837
# Cost after iteration  578000  is  258.5619162395138
# Cost after iteration  578500  is  258.7188993138162
# Cost after iteration  579000  is  258.8757352907994
# Cost after iteration  579500  is  259.03242421027426
# Cost after iteration  580000  is  259.18896611240626
# Cost after iteration  580500  is  259.3453610377252
# Cost after iteration  581000  is  259.5016090271162
# Cost after iteration  581500  is  259.65771012181915
# Cost after iteration  582000  is  259.8136643634298
# Cost after iteration  582500  is  259.96947179389514
# Cost after iteration  583000  is  260.1251324555152
# Cost after iteration  583500  is  260.28064639093793
# Cost after iteration  584000  is  260.43601364316186
# Cost after iteration  584500  is  260.59123425552843
# Cost after iteration  585000  is  260.7463082717262
# Cost after iteration  585500  is  260.90123573578785
# Cost after iteration  586000  is  261.0560166920884
# Cost after iteration  586500  is  261.21065118534045
# Cost after iteration  587000  is  261.3651392605976
# Cost after iteration  587500  is  261.5194809632525
# Cost after iteration  588000  is  261.6736763390272
# Cost after iteration  588500  is  261.8277254339854
# Cost after iteration  589000  is  261.9816282945208
# Cost after iteration  589500  is  262.13538496735697
# Cost after iteration  590000  is  262.28899549955133
# Cost after iteration  590500  is  262.4424599384862
# Cost after iteration  591000  is  262.5957783318725
# Cost after iteration  591500  is  262.7489507277455
# Cost after iteration  592000  is  262.90197717446665
# Cost after iteration  592500  is  263.05485772071745
# Cost after iteration  593000  is  263.2075924155013
# Cost after iteration  593500  is  263.36018130814176
# Cost after iteration  594000  is  263.51262444827984
# Cost after iteration  594500  is  263.6649218858737
# Cost after iteration  595000  is  263.8170736711989
# Cost after iteration  595500  is  263.9690798548407
# Cost after iteration  596000  is  264.12094048770064
# Cost after iteration  596500  is  264.27265562098796
# Cost after iteration  597000  is  264.4242253062246
# Cost after iteration  597500  is  264.57564959523785
# Cost after iteration  598000  is  264.7269285401646
# Cost after iteration  598500  is  264.87806219344395
# Cost after iteration  599000  is  265.0290506078209
# Cost after iteration  599500  is  265.17989383634244
# Cost after iteration  600000  is  265.3305919323576
# Cost after iteration  600500  is  265.48114494951443
# Cost after iteration  601000  is  265.63155294175857
# Cost after iteration  601500  is  265.78181596333496
# Cost after iteration  602000  is  265.9319340687818
# Cost after iteration  602500  is  266.08190731293234
# Cost after iteration  603000  is  266.23173575091397
# Cost after iteration  603500  is  266.38141943814367
# Cost after iteration  604000  is  266.5309584303295
# Cost after iteration  604500  is  266.6803527834675
# Cost after iteration  605000  is  266.82960255384256
# Cost after iteration  605500  is  266.97870779802514
# Cost after iteration  606000  is  267.1276685728709
# Cost after iteration  606500  is  267.2764849355165
# Cost after iteration  607000  is  267.42515694338374
# Cost after iteration  607500  is  267.57368465417585
# Cost after iteration  608000  is  267.72206812587115
# Cost after iteration  608500  is  267.8703074167293
# Cost after iteration  609000  is  268.01840258528665
# Cost after iteration  609500  is  268.16635369035424
# Cost after iteration  610000  is  268.31416079101837
# Cost after iteration  610500  is  268.4618239466357
# Cost after iteration  611000  is  268.6093432168398
# Cost after iteration  611500  is  268.7567186615277
# Cost after iteration  612000  is  268.90395034086947
# Cost after iteration  612500  is  269.05103831530107
# Cost after iteration  613000  is  269.19798264552855
# Cost after iteration  613500  is  269.3447833925191
# Cost after iteration  614000  is  269.4914406175064
# Cost after iteration  614500  is  269.63795438198565
# Cost after iteration  615000  is  269.7843247477118
# Cost after iteration  615500  is  269.9305517767045
# Cost after iteration  616000  is  270.076635531237
# Cost after iteration  616500  is  270.2225760738435
# Cost after iteration  617000  is  270.3683734673133
# Cost after iteration  617500  is  270.514027774691
# Cost after iteration  618000  is  270.6595390592766
# Cost after iteration  618500  is  270.80490738461947
# Cost after iteration  619000  is  270.9501328145234
# Cost after iteration  619500  is  271.09521541304144
# Cost after iteration  620000  is  271.2401552444739
# Cost after iteration  620500  is  271.3849523733717
# Cost after iteration  621000  is  271.5296068645309
# Cost after iteration  621500  is  271.6741187829918
# Cost after iteration  622000  is  271.8184881940399
# Cost after iteration  622500  is  271.96271516320377
# Cost after iteration  623000  is  272.10679975625385
# Cost after iteration  623500  is  272.250742039201
# Cost after iteration  624000  is  272.3945420782946
# Cost after iteration  624500  is  272.53819994002254
# Cost after iteration  625000  is  272.6817156911103
# Cost after iteration  625500  is  272.8250893985196
# Cost after iteration  626000  is  272.96832112944355
# Cost after iteration  626500  is  273.11141095131126
# Cost after iteration  627000  is  273.2543589317851
# Cost after iteration  627500  is  273.39716513875493
# Cost after iteration  628000  is  273.53982964034446
# Cost after iteration  628500  is  273.68235250490454
# Cost after iteration  629000  is  273.82473380101163
# Cost after iteration  629500  is  273.96697359747327
# Cost after iteration  630000  is  274.1090719633189
# Cost after iteration  630500  is  274.2510289678008
# Cost after iteration  631000  is  274.39284468039875
# Cost after iteration  631500  is  274.5345191708116
# Cost after iteration  632000  is  274.67605250895804
# Cost after iteration  632500  is  274.81744476497835
# Cost after iteration  633000  is  274.9586960092321
# Cost after iteration  633500  is  275.09980631229234
# Cost after iteration  634000  is  275.24077574495243
# Cost after iteration  634500  is  275.38160437821927
# Cost after iteration  635000  is  275.5222922833148
# Cost after iteration  635500  is  275.6628395316727
# Cost after iteration  636000  is  275.8032461949377
# Cost after iteration  636500  is  275.94351234496906
# Cost after iteration  637000  is  276.08363805383084
# Cost after iteration  637500  is  276.2236233937998
# Cost after iteration  638000  is  276.3634684373577
# Cost after iteration  638500  is  276.5031732571951
# Cost after iteration  639000  is  276.6427379262028
# Cost after iteration  639500  is  276.7821625174821
# Cost after iteration  640000  is  276.92144710433405
# Cost after iteration  640500  is  277.0605917602627
# Cost after iteration  641000  is  277.19959655897327
# Cost after iteration  641500  is  277.3384615743701
# Cost after iteration  642000  is  277.4771868805577
# Cost after iteration  642500  is  277.61577255183767
# Cost after iteration  643000  is  277.75421866270744
# Cost after iteration  643500  is  277.89252528786403
# Cost after iteration  644000  is  278.0306925021946
# Cost after iteration  644500  is  278.16872038078424
# Cost after iteration  645000  is  278.3066089989052
# Cost after iteration  645500  is  278.4443584320266
# Cost after iteration  646000  is  278.5819687558061
# Cost after iteration  646500  is  278.719440046093
# Cost after iteration  647000  is  278.85677237892077
# Cost after iteration  647500  is  278.99396583051316
# Cost after iteration  648000  is  279.13102047728046
# Cost after iteration  648500  is  279.2679363958176
# Cost after iteration  649000  is  279.4047136629067
# Cost after iteration  649500  is  279.54135235550905
# Cost after iteration  650000  is  279.6778525507723
# Cost after iteration  650500  is  279.8142143260229
# Cost after iteration  651000  is  279.9504377587704
# Cost after iteration  651500  is  280.08652292670155
# Cost after iteration  652000  is  280.22246990768275
# Cost after iteration  652500  is  280.35827877975856
# Cost after iteration  653000  is  280.4939496211469
# Cost after iteration  653500  is  280.6294825102446
# Cost after iteration  654000  is  280.7648775256221
# Cost after iteration  654500  is  280.9001347460231
# Cost after iteration  655000  is  281.0352542503639
# Cost after iteration  655500  is  281.1702361177346
# Cost after iteration  656000  is  281.30508042739365
# Cost after iteration  656500  is  281.43978725876786
# Cost after iteration  657000  is  281.5743566914576
# Cost after iteration  657500  is  281.7087888052264
# Cost after iteration  658000  is  281.843083680009
# Cost after iteration  658500  is  281.97724139590247
# Cost after iteration  659000  is  282.11126203317036
# Cost after iteration  659500  is  282.2451456722392
# Cost after iteration  660000  is  282.3788923937013
# Cost after iteration  660500  is  282.51250227830906
# Cost after iteration  661000  is  282.64597540697594
# Cost after iteration  661500  is  282.7793118607776
# Cost after iteration  662000  is  282.9125117209467
# Cost after iteration  662500  is  283.045575068877
# Cost after iteration  663000  is  283.1785019861175
# Cost after iteration  663500  is  283.3112925543767
# Cost after iteration  664000  is  283.44394685551447
# Cost after iteration  664500  is  283.57646497154997
# Cost after iteration  665000  is  283.7088469846551
# Cost after iteration  665500  is  283.8410929771515
# Cost after iteration  666000  is  283.97320303151713
# Cost after iteration  666500  is  284.1051772303811
# Cost after iteration  667000  is  284.23701565651993
# Cost after iteration  667500  is  284.36871839286084
# Cost after iteration  668000  is  284.5002855224809
# Cost after iteration  668500  is  284.63171712860344
# Cost after iteration  669000  is  284.76301329460085
# Cost after iteration  669500  is  284.8941741039874
# Cost after iteration  670000  is  285.02519964042585
# Cost after iteration  670500  is  285.15608998772154
# Cost after iteration  671000  is  285.2868452298236
# Cost after iteration  671500  is  285.41746545082447
# Cost after iteration  672000  is  285.5479507349569
# Cost after iteration  672500  is  285.67830116659445
# Cost after iteration  673000  is  285.808516830251
# Cost after iteration  673500  is  285.93859781058006
# Cost after iteration  674000  is  286.0685441923727
# Cost after iteration  674500  is  286.19835606055625
# Cost after iteration  675000  is  286.32803350019634
# Cost after iteration  675500  is  286.45757659649246
# Cost after iteration  676000  is  286.5869854347794
# Cost after iteration  676500  is  286.716260100528
# Cost after iteration  677000  is  286.84540067933875
# Cost after iteration  677500  is  286.9744072569475
# Cost after iteration  678000  is  287.1032799192191
# Cost after iteration  678500  is  287.23201875215113
# Cost after iteration  679000  is  287.3606238418694
# Cost after iteration  679500  is  287.48909527462973
# Cost after iteration  680000  is  287.6174331368135
# Cost after iteration  680500  is  287.7456375149342
# Cost after iteration  681000  is  287.87370849562893
# Cost after iteration  681500  is  288.00164616565945
# Cost after iteration  682000  is  288.1294506119155
# Cost after iteration  682500  is  288.2571219214095
# Cost after iteration  683000  is  288.3846601812758
# Cost after iteration  683500  is  288.5120654787731
# Cost after iteration  684000  is  288.63933790128107
# Cost after iteration  684500  is  288.7664775362995
# Cost after iteration  685000  is  288.89348447145
# Cost after iteration  685500  is  289.02035879447266
# Cost after iteration  686000  is  289.14710059322744
# Cost after iteration  686500  is  289.27370995568947
# Cost after iteration  687000  is  289.40018696995185
# Cost after iteration  687500  is  289.5265317242251
# Cost after iteration  688000  is  289.6527443068344
# Cost after iteration  688500  is  289.7788248062218
# Cost after iteration  689000  is  289.9047733109377
# Cost after iteration  689500  is  290.03058990965116
# Cost after iteration  690000  is  290.1562746911417
# Cost after iteration  690500  is  290.2818277443002
# Cost after iteration  691000  is  290.40724915812893
# Cost after iteration  691500  is  290.53253902173856
# Cost after iteration  692000  is  290.657697424353
# Cost after iteration  692500  is  290.7827244553
# Cost after iteration  693000  is  290.90762020401894
# Cost after iteration  693500  is  291.03238476005464
# Cost after iteration  694000  is  291.15701821306004
# Cost after iteration  694500  is  291.28152065278937
# Cost after iteration  695000  is  291.4058921691066
# Cost after iteration  695500  is  291.5301328519774
# Cost after iteration  696000  is  291.65424279147203
# Cost after iteration  696500  is  291.7782220777623
# Cost after iteration  697000  is  291.90207080112225
# Cost after iteration  697500  is  292.02578905192814
# Cost after iteration  698000  is  292.14937692065524
# Cost after iteration  698500  is  292.27283449788166
# Cost after iteration  699000  is  292.39616187428084
# Cost after iteration  699500  is  292.5193591406269

# %%
# Performance on the Test Set
y_predicted = predict(X_test3, weights)
print("MSE on test set is: ",mse(y_predicted, Y_test3, weights))
# Out:
# MSE on test set is:  299.4228623863

# %% [markdown]
# ### By using Normal Equation

# %%
def normal_eq(X_train3, Y_train3, lamda=4):
    
    extra_x = np.zeros((X_train3.shape[1],X_train3.shape[1]))
    
    for i in range(1,X_train3.shape[1]):
        extra_x[i,i]=1

    a1 =np.dot(X_train3.T, X_train3)
    a2 = np.dot(X_train3.T, Y_train3)
    theta3 = np.dot(np.linalg.inv(a1 + lamda*extra_x), a2)
    
    return theta3

# %%
# Using Normal Equation
weights3=normal_eq(X_train3, Y_train3)
y_predicted = predict(X_test3, weights3)
print("MSE on test set is: ",mse(y_predicted, Y_test3, weights3))
# Out:
# MSE on test set is:  5287.074108432613
